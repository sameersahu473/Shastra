# %% [markdown]
# <a href="https://colab.research.google.com/github/sameersahu473/Shastra/blob/main/13_jan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.62.3)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (5.0.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2021.10.8)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)

# %% [markdown]
# # New Section

# %%
! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle competitions download kick-off
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.12 / client 1.5.4)
# Downloading FIFA_train.csv.zip to /content
#   0% 0.00/5.82M [00:00<?, ?B/s]
# 100% 5.82M/5.82M [00:00<00:00, 92.4MB/s]
# Downloading FIFA_test.csv to /content
#   0% 0.00/130k [00:00<?, ?B/s]
# 100% 130k/130k [00:00<00:00, 123MB/s]
# Downloading FIFA_test_player_data.csv.zip to /content
#   0% 0.00/2.32M [00:00<?, ?B/s]
# 100% 2.32M/2.32M [00:00<00:00, 77.5MB/s]
# Downloading sample_submission.csv to /content
#   0% 0.00/140k [00:00<?, ?B/s]
# 100% 140k/140k [00:00<00:00, 135MB/s]

# %%
! unzip FIFA_test_player_data.csv.zip
# Out:
# Archive:  FIFA_test_player_data.csv.zip
#   inflating: FIFA_test_player_data.csv

# %%
! unzip FIFA_train.csv.zip
# Out:
# Archive:  FIFA_train.csv.zip
#   inflating: FIFA_train.csv

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('FIFA_train.csv')
df_test = pd.read_csv('FIFA_test_player_data.csv')

# %%
df_test_l = df_test['sofifa_id']

# %%
df.shape
# Out:
# (37548, 103)

# %%
df.head()
# Out:
#    sofifa_id                                         player_url  ...   rcb    rb
# 0     216393  https://sofifa.com/player/216393/youri-tielema...  ...  69+2  69+2
# 1     187878  https://sofifa.com/player/187878/lukas-marecek...  ...  68+2  70+2
# 2     178628  https://sofifa.com/player/178628/fernando-fore...  ...  56+2  58+2
# 3     184341  https://sofifa.com/player/184341/riccardo-mani...  ...  44+2  41+2
# 4     231933  https://sofifa.com/player/231933/rowllin-borge...  ...  58+1  57+1
#
# [5 rows x 103 columns]

# %%
df_test.head()
# Out:
#    sofifa_id                                         player_url  ...   rcb    rb
# 0     167495  https://sofifa.com/player/167495/manuel-neuer/...  ...   NaN   NaN
# 1     155862  https://sofifa.com/player/155862/sergio-ramos-...  ...  87+3  84+3
# 2     182521  https://sofifa.com/player/182521/toni-kroos/18...  ...  73+3  76+3
# 3     138956  https://sofifa.com/player/138956/giorgio-chiel...  ...  87+3  79+3
# 4       9014  https://sofifa.com/player/9014/arjen-robben/18...  ...  47+3  58+3
#
# [5 rows x 102 columns]

# %%
df.describe()
# Out:
#            sofifa_id           age  ...     gk_speed  gk_positioning
# count   37548.000000  37548.000000  ...  4192.000000     4192.000000
# mean   213684.446895     25.213726  ...    38.595420       63.188216
# std     30601.734513      4.655781  ...    10.460477        8.631960
# min       164.000000     16.000000  ...    12.000000       38.000000
# 25%    199510.750000     21.000000  ...    30.000000       58.000000
# 50%    221168.000000     25.000000  ...    40.000000       64.000000
# 75%    235896.250000     29.000000  ...    46.000000       69.000000
# max    252905.000000     47.000000  ...    65.000000       91.000000
#
# [8 rows x 26 columns]

# %%
for i in range(len(df.columns)):
    print(i+1, ": ", df.columns[i])
# Out:
# 1 :  sofifa_id
# 2 :  player_url
# 3 :  short_name
# 4 :  long_name
# 5 :  age
# 6 :  dob
# 7 :  height_cm
# 8 :  weight_kg
# 9 :  nationality
# 10 :  club
# 11 :  overall
# 12 :  potential
# 13 :  value
# 14 :  player_positions
# 15 :  preferred_foot
# 16 :  international_reputation
# 17 :  weak_foot
# 18 :  skill_moves
# 19 :  work_rate
# 20 :  body_type
# 21 :  real_face
# 22 :  release_clause_eur
# 23 :  player_tags
# 24 :  team_position
# 25 :  team_jersey_number
# 26 :  loaned_from
# 27 :  joined
# 28 :  contract_valid_until
# 29 :  nation_position
# 30 :  nation_jersey_number
# 31 :  pace
# 32 :  shooting
# 33 :  passing
# 34 :  dribbling
# 35 :  defending
# 36 :  physic
# 37 :  gk_diving
# 38 :  gk_handling
# 39 :  gk_kicking
# 40 :  gk_reflexes
# 41 :  gk_speed
# 42 :  gk_positioning
# 43 :  player_traits
# 44 :  attacking_crossing
# 45 :  attacking_finishing
# 46 :  attacking_heading_accuracy
# 47 :  attacking_short_passing
# 48 :  attacking_volleys
# 49 :  skill_dribbling
# 50 :  skill_curve
# 51 :  skill_fk_accuracy
# 52 :  skill_long_passing
# 53 :  skill_ball_control
# 54 :  movement_acceleration
# 55 :  movement_sprint_speed
# 56 :  movement_agility
# 57 :  movement_reactions
# 58 :  movement_balance
# 59 :  power_shot_power
# 60 :  power_jumping
# 61 :  power_stamina
# 62 :  power_strength
# 63 :  power_long_shots
# 64 :  mentality_aggression
# 65 :  mentality_interceptions
# 66 :  mentality_positioning
# 67 :  mentality_vision
# 68 :  mentality_penalties
# 69 :  mentality_composure
# 70 :  defending_marking
# 71 :  defending_standing_tackle
# 72 :  defending_sliding_tackle
# 73 :  goalkeeping_diving
# 74 :  goalkeeping_handling
# 75 :  goalkeeping_kicking
# 76 :  goalkeeping_positioning
# 77 :  goalkeeping_reflexes
# 78 :  ls
# 79 :  st
# 80 :  rs
# 81 :  lw
# 82 :  lf
# 83 :  cf
# 84 :  rf
# 85 :  rw
# 86 :  lam
# 87 :  cam
# 88 :  ram
# 89 :  lm
# 90 :  lcm
# 91 :  cm
# 92 :  rcm
# 93 :  rm
# 94 :  lwb
# 95 :  ldm
# 96 :  cdm
# 97 :  rdm
# 98 :  rwb
# 99 :  lb
# 100 :  lcb
# 101 :  cb
# 102 :  rcb
# 103 :  rb

# %%
df.isnull().sum()
# Out:
# sofifa_id        0
# player_url       0
# short_name       0
# long_name        0
# age              0
#               ...
# lb            4192
# lcb           4192
# cb            4192
# rcb           4192
# rb            4192
# Length: 103, dtype: int64

# %%
for col in df.columns:  
    dataTypeSeries = df[col].dtypes
    print('Data type of '+ col+ ' column of Dataframe :')
    print(dataTypeSeries)
# Out:
# Data type of sofifa_id column of Dataframe :
# int64
# Data type of player_url column of Dataframe :
# object
# Data type of short_name column of Dataframe :
# object
# Data type of long_name column of Dataframe :
# object
# Data type of age column of Dataframe :
# int64
# Data type of dob column of Dataframe :
# object
# Data type of height_cm column of Dataframe :
# int64
# Data type of weight_kg column of Dataframe :
# int64
# Data type of nationality column of Dataframe :
# object
# Data type of club column of Dataframe :
# object
# Data type of overall column of Dataframe :
# int64
# Data type of potential column of Dataframe :
# int64
# Data type of value column of Dataframe :
# int64
# Data type of player_positions column of Dataframe :
# object
# Data type of preferred_foot column of Dataframe :
# object
# Data type of international_reputation column of Dataframe :
# int64
# Data type of weak_foot column of Dataframe :
# int64
# Data type of skill_moves column of Dataframe :
# int64
# Data type of work_rate column of Dataframe :
# object
# Data type of body_type column of Dataframe :
# object
# Data type of real_face column of Dataframe :
# object
# Data type of release_clause_eur column of Dataframe :
# float64
# Data type of player_tags column of Dataframe :
# object
# Data type of team_position column of Dataframe :
# object
# Data type of team_jersey_number column of Dataframe :
# float64
# Data type of loaned_from column of Dataframe :
# object
# Data type of joined column of Dataframe :
# object
# Data type of contract_valid_until column of Dataframe :
# float64
# Data type of nation_position column of Dataframe :
# object
# Data type of nation_jersey_number column of Dataframe :
# float64
# Data type of pace column of Dataframe :
# float64
# Data type of shooting column of Dataframe :
# float64
# Data type of passing column of Dataframe :
# float64
# Data type of dribbling column of Dataframe :
# float64
# Data type of defending column of Dataframe :
# float64
# Data type of physic column of Dataframe :
# float64
# Data type of gk_diving column of Dataframe :
# float64
# Data type of gk_handling column of Dataframe :
# float64
# Data type of gk_kicking column of Dataframe :
# float64
# Data type of gk_reflexes column of Dataframe :
# float64
# Data type of gk_speed column of Dataframe :
# float64
# Data type of gk_positioning column of Dataframe :
# float64
# Data type of player_traits column of Dataframe :
# object
# Data type of attacking_crossing column of Dataframe :
# object
# Data type of attacking_finishing column of Dataframe :
# object
# Data type of attacking_heading_accuracy column of Dataframe :
# object
# Data type of attacking_short_passing column of Dataframe :
# object
# Data type of attacking_volleys column of Dataframe :
# object
# Data type of skill_dribbling column of Dataframe :
# object
# Data type of skill_curve column of Dataframe :
# object
# Data type of skill_fk_accuracy column of Dataframe :
# object
# Data type of skill_long_passing column of Dataframe :
# object
# Data type of skill_ball_control column of Dataframe :
# object
# Data type of movement_acceleration column of Dataframe :
# object
# Data type of movement_sprint_speed column of Dataframe :
# object
# Data type of movement_agility column of Dataframe :
# object
# Data type of movement_reactions column of Dataframe :
# object
# Data type of movement_balance column of Dataframe :
# object
# Data type of power_shot_power column of Dataframe :
# object
# Data type of power_jumping column of Dataframe :
# object
# Data type of power_stamina column of Dataframe :
# object
# Data type of power_strength column of Dataframe :
# object
# Data type of power_long_shots column of Dataframe :
# object
# Data type of mentality_aggression column of Dataframe :
# object
# Data type of mentality_interceptions column of Dataframe :
# object
# Data type of mentality_positioning column of Dataframe :
# object
# Data type of mentality_vision column of Dataframe :
# object
# Data type of mentality_penalties column of Dataframe :
# object
# Data type of mentality_composure column of Dataframe :
# object
# Data type of defending_marking column of Dataframe :
# object
# Data type of defending_standing_tackle column of Dataframe :
# object
# Data type of defending_sliding_tackle column of Dataframe :
# object
# Data type of goalkeeping_diving column of Dataframe :
# object
# Data type of goalkeeping_handling column of Dataframe :
# object
# Data type of goalkeeping_kicking column of Dataframe :
# object
# Data type of goalkeeping_positioning column of Dataframe :
# object
# Data type of goalkeeping_reflexes column of Dataframe :
# object
# Data type of ls column of Dataframe :
# object
# Data type of st column of Dataframe :
# object
# Data type of rs column of Dataframe :
# object
# Data type of lw column of Dataframe :
# object
# Data type of lf column of Dataframe :
# object
# Data type of cf column of Dataframe :
# object
# Data type of rf column of Dataframe :
# object
# Data type of rw column of Dataframe :
# object
# Data type of lam column of Dataframe :
# object
# Data type of cam column of Dataframe :
# object
# Data type of ram column of Dataframe :
# object
# Data type of lm column of Dataframe :
# object
# Data type of lcm column of Dataframe :
# object
# Data type of cm column of Dataframe :
# object
# Data type of rcm column of Dataframe :
# object
# Data type of rm column of Dataframe :
# object
# Data type of lwb column of Dataframe :
# object
# Data type of ldm column of Dataframe :
# object
# Data type of cdm column of Dataframe :
# object
# Data type of rdm column of Dataframe :
# object
# Data type of rwb column of Dataframe :
# object
# Data type of lb column of Dataframe :
# object
# Data type of lcb column of Dataframe :
# object
# Data type of cb column of Dataframe :
# object
# Data type of rcb column of Dataframe :
# object
# Data type of rb column of Dataframe :
# object

# %%
index_no = df.columns.get_loc('mentality_positioning')
index_no
# Out:
# 65

# %%
sns.heatmap(df.isnull(),yticklabels= False,cbar =False,cmap ='viridis')

# %%
df_test.isnull().sum()
# Out:
# sofifa_id        0
# player_url       0
# short_name       0
# long_name        0
# age              0
#               ...
# lb            1809
# lcb           1809
# cb            1809
# rcb           1809
# rb            1809
# Length: 102, dtype: int64

# %%
index_no = df.columns.get_loc('attacking_crossing')
index_no
# Out:
# 43

# %%
colseries = df.columns[43:]

# %%
colseries
# Out:
# Index(['attacking_crossing', 'attacking_finishing',
#        'attacking_heading_accuracy', 'attacking_short_passing',
#        'attacking_volleys', 'skill_dribbling', 'skill_curve',
#        'skill_fk_accuracy', 'skill_long_passing', 'skill_ball_control',
#        'movement_acceleration', 'movement_sprint_speed', 'movement_agility',
#        'movement_reactions', 'movement_balance', 'power_shot_power',
#        'power_jumping', 'power_stamina', 'power_strength', 'power_long_shots',
#        'mentality_aggression', 'mentality_interceptions',
#        'mentality_positioning', 'mentality_vision', 'mentality_penalties',
#        'mentality_composure', 'defending_marking', 'defending_standing_tackle',
#        'defending_sliding_tackle', 'goalkeeping_diving',
#        'goalkeeping_handling', 'goalkeeping_kicking',
#        'goalkeeping_positioning', 'goalkeeping_reflexes', 'ls', 'st', 'rs',
#        'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm',
#        'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb',
#        'rcb', 'rb'],
#       dtype='object')

# %%
def transform(str):
  if len(str)== 0 :
     return 0
  
  else:
    if len(str) ==3:
      return int(str[0:1])
    else:
     return int(str[0:2])

# %%
def convert_attributes(number_str):
  if type(number_str) == str:
    if '+' in number_str:
      return float(number_str.split('+')[0])
    elif '-' in number_str:
      return float(number_str.split('-')[0])
    else:
      return float(number_str)

# %%
#df[colseries] = df[colseries].apply(transform)
#df[colseries] = transform(df[colseries])

for cols in colseries:
  df[cols] = df[cols].apply(convert_attributes)


for cols in colseries:
  df[cols].replace(np.nan,0)


for cols in colseries:
  df_test[cols] = df_test[cols].apply(convert_attributes)


for cols in colseries:
  df_test[cols].replace(np.nan,0)

# %%
delcols = ['sofifa_id','player_url','short_name','long_name','dob','nation_jersey_number']

df =df.drop(delcols, axis=1)
df_test =df_test.drop(delcols,axis=1)

# %%
df['mentality_positioning'].dtypes
# Out:
# dtype('float64')

# %%
df.head(15)
# Out:
#     age  height_cm  weight_kg          nationality  ...   lcb    cb   rcb    rb
# 0    21        176         72              Belgium  ...  69.0  69.0  69.0  69.0
# 1    28        183         79       Czech Republic  ...  68.0  68.0  68.0  70.0
# 2    29        172         67                Italy  ...  56.0  56.0  56.0  58.0
# 3    31        183         75                Italy  ...  44.0  44.0  44.0  41.0
# 4    25        185         75                India  ...  58.0  58.0  58.0  57.0
# 5    26        183         75                Japan  ...  65.0  65.0  65.0  66.0
# 6    38        191         93              England  ...   NaN   NaN   NaN   NaN
# 7    23        190         81                Spain  ...  37.0  37.0  37.0  37.0
# 8    20        189         79               Sweden  ...  55.0  55.0  55.0  51.0
# 9    23        187         72              Germany  ...  49.0  49.0  49.0  58.0
# 10   19        178         72             Colombia  ...  41.0  41.0  41.0  44.0
# 11   25        175         72             Scotland  ...  35.0  35.0  35.0  45.0
# 12   31        192         78             China PR  ...   NaN   NaN   NaN   NaN
# 13   19        182         75               France  ...  62.0  62.0  62.0  57.0
# 14   26        178         76  Republic of Ireland  ...  56.0  56.0  56.0  57.0
#
# [15 rows x 97 columns]

# %%
cat_col = [c for i, c in enumerate(df.columns) if df.dtypes[i] in [np.object]]
cat_col
# Out:
# ['nationality',
#  'club',
#  'player_positions',
#  'preferred_foot',
#  'work_rate',
#  'body_type',
#  'real_face',
#  'player_tags',
#  'team_position',
#  'loaned_from',
#  'joined',
#  'nation_position',
#  'player_traits']

# %%
df['player_traits'].value_counts()
# Out:
# Injury Prone                                                                                                         632
# Speed Dribbler (CPU AI Only)                                                                                         577
# Early Crosser                                                                                                        532
# Long Passer (CPU AI Only)                                                                                            508
# Dives Into Tackles (CPU AI Only)                                                                                     450
#                                                                                                                     ...
# Avoids Using Weaker Foot, Cautious With Crosses, Saves with Feet                                                       1
# Diver, Injury Free, Speed Dribbler (CPU AI Only), Team Player                                                          1
# Diver, Flair, Long Shot Taker (CPU AI Only), Playmaker (CPU AI Only), Backs Into Player, Takes Finesse Free Kicks      1
# Leadership, Finesse Shot, Backs Into Player, Takes Finesse Free Kicks                                                  1
# Diver, Selfish, Finesse Shot, Flair, Outside Foot Shot, Technical Dribbler (CPU AI Only)                               1
# Name: player_traits, Length: 2310, dtype: int64

# %%
catcol = ['nationality','club','preferred_foot','work_rate','body_type','real_face','player_tags','team_position','loaned_from','nation_position']

# %%
# Import label encoder
from sklearn import preprocessing
 
# label_encoder object knows how to understand word labels.
label_encoder= preprocessing.LabelEncoder()
 
# Encode labels in column 'species'.
#df['species']= label_encoder.fit_transform(df['species'])
for col in catcol:
  df[col]= label_encoder.fit_transform(df[col])
  df_test[col] = label_encoder.fit_transform(df_test[col])

# %%
df.head(15)
# Out:
#     age  height_cm  weight_kg  nationality  club  ...    lb   lcb    cb   rcb    rb
# 0    21        176         72           13    18  ...  69.0  69.0  69.0  69.0  69.0
# 1    28        183         79           39   703  ...  70.0  68.0  68.0  68.0  70.0
# 2    29        172         67           78   680  ...  58.0  56.0  56.0  56.0  58.0
# 3    31        183         75           78   558  ...  41.0  44.0  44.0  44.0  41.0
# 4    25        185         75           73   409  ...  57.0  58.0  58.0  58.0  57.0
# 5    26        183         75           81   392  ...  66.0  65.0  65.0  65.0  66.0
# 6    38        191         93           46   169  ...   NaN   NaN   NaN   NaN   NaN
# 7    23        190         81          141   139  ...  37.0  37.0  37.0  37.0  37.0
# 8    20        189         79          148    85  ...  51.0  55.0  55.0  55.0  51.0
# 9    23        187         72           58   550  ...  58.0  49.0  49.0  49.0  58.0
# 10   19        178         72           31   258  ...  44.0  41.0  41.0  41.0  44.0
# 11   25        175         72          133   380  ...  45.0  35.0  35.0  35.0  45.0
# 12   31        192         78           30   384  ...   NaN   NaN   NaN   NaN   NaN
# 13   19        182         75           54   108  ...  57.0  62.0  62.0  62.0  57.0
# 14   26        178         76          127   688  ...  57.0  56.0  56.0  56.0  57.0
#
# [15 rows x 97 columns]

# %%
df_test.head()
# Out:
#    age  height_cm  weight_kg  nationality  club  ...    lb   lcb    cb   rcb    rb
# 0   31        193         92           56   271  ...   NaN   NaN   NaN   NaN   NaN
# 1   31        183         75          133   592  ...  84.0  87.0  87.0  87.0  84.0
# 2   27        182         78           56   592  ...  76.0  73.0  73.0  73.0  76.0
# 3   32        187         85           74   418  ...  79.0  87.0  87.0  87.0  79.0
# 4   33        180         80          103   271  ...  58.0  47.0  47.0  47.0  58.0
#
# [5 rows x 96 columns]

# %%
for cols in catcol:
  df[cols].replace(np.nan,0)
  df_test[cols].replace(np.nan,0)

# %%
sns.heatmap(df.isnull(),yticklabels= False,cbar =False,cmap ='viridis')

# %%
mulcols = ['player_traits','player_positions','joined']

# %%
df =df.drop(mulcols, axis=1)
df_test =df_test.drop(mulcols, axis=1)

# %%
df.head()
# Out:
#    age  height_cm  weight_kg  nationality  club  ...    lb   lcb    cb   rcb    rb
# 0   21        176         72           13    18  ...  69.0  69.0  69.0  69.0  69.0
# 1   28        183         79           39   703  ...  70.0  68.0  68.0  68.0  70.0
# 2   29        172         67           78   680  ...  58.0  56.0  56.0  56.0  58.0
# 3   31        183         75           78   558  ...  41.0  44.0  44.0  44.0  41.0
# 4   25        185         75           73   409  ...  57.0  58.0  58.0  58.0  57.0
#
# [5 rows x 94 columns]

# %%
sns.heatmap(df.isnull(),yticklabels= False,cbar =False,cmap ='viridis')

# %%
df = df.fillna(0)
df_test = df_test.fillna(0)

# %%
sns.heatmap(df.isnull(),yticklabels= False,cbar =False,cmap ='viridis')

# %%
df.head()
# Out:
#    age  height_cm  weight_kg  nationality  club  ...    lb   lcb    cb   rcb    rb
# 0   21        176         72           13    18  ...  69.0  69.0  69.0  69.0  69.0
# 1   28        183         79           39   703  ...  70.0  68.0  68.0  68.0  70.0
# 2   29        172         67           78   680  ...  58.0  56.0  56.0  56.0  58.0
# 3   31        183         75           78   558  ...  41.0  44.0  44.0  44.0  41.0
# 4   25        185         75           73   409  ...  57.0  58.0  58.0  58.0  57.0
#
# [5 rows x 94 columns]

# %%
for col in df.columns:  
    dataTypeSeries = df[col].dtypes
    print('Data type of '+ col+ ' column of Dataframe :')
    print(dataTypeSeries)
# Out:
# Data type of age column of Dataframe :
# int64
# Data type of height_cm column of Dataframe :
# int64
# Data type of weight_kg column of Dataframe :
# int64
# Data type of nationality column of Dataframe :
# int64
# Data type of club column of Dataframe :
# int64
# Data type of overall column of Dataframe :
# int64
# Data type of potential column of Dataframe :
# int64
# Data type of value column of Dataframe :
# int64
# Data type of preferred_foot column of Dataframe :
# int64
# Data type of international_reputation column of Dataframe :
# int64
# Data type of weak_foot column of Dataframe :
# int64
# Data type of skill_moves column of Dataframe :
# int64
# Data type of work_rate column of Dataframe :
# int64
# Data type of body_type column of Dataframe :
# int64
# Data type of real_face column of Dataframe :
# int64
# Data type of release_clause_eur column of Dataframe :
# float64
# Data type of player_tags column of Dataframe :
# int64
# Data type of team_position column of Dataframe :
# int64
# Data type of team_jersey_number column of Dataframe :
# float64
# Data type of loaned_from column of Dataframe :
# int64
# Data type of contract_valid_until column of Dataframe :
# float64
# Data type of nation_position column of Dataframe :
# int64
# Data type of pace column of Dataframe :
# float64
# Data type of shooting column of Dataframe :
# float64
# Data type of passing column of Dataframe :
# float64
# Data type of dribbling column of Dataframe :
# float64
# Data type of defending column of Dataframe :
# float64
# Data type of physic column of Dataframe :
# float64
# Data type of gk_diving column of Dataframe :
# float64
# Data type of gk_handling column of Dataframe :
# float64
# Data type of gk_kicking column of Dataframe :
# float64
# Data type of gk_reflexes column of Dataframe :
# float64
# Data type of gk_speed column of Dataframe :
# float64
# Data type of gk_positioning column of Dataframe :
# float64
# Data type of attacking_crossing column of Dataframe :
# float64
# Data type of attacking_finishing column of Dataframe :
# float64
# Data type of attacking_heading_accuracy column of Dataframe :
# float64
# Data type of attacking_short_passing column of Dataframe :
# float64
# Data type of attacking_volleys column of Dataframe :
# float64
# Data type of skill_dribbling column of Dataframe :
# float64
# Data type of skill_curve column of Dataframe :
# float64
# Data type of skill_fk_accuracy column of Dataframe :
# float64
# Data type of skill_long_passing column of Dataframe :
# float64
# Data type of skill_ball_control column of Dataframe :
# float64
# Data type of movement_acceleration column of Dataframe :
# float64
# Data type of movement_sprint_speed column of Dataframe :
# float64
# Data type of movement_agility column of Dataframe :
# float64
# Data type of movement_reactions column of Dataframe :
# float64
# Data type of movement_balance column of Dataframe :
# float64
# Data type of power_shot_power column of Dataframe :
# float64
# Data type of power_jumping column of Dataframe :
# float64
# Data type of power_stamina column of Dataframe :
# float64
# Data type of power_strength column of Dataframe :
# float64
# Data type of power_long_shots column of Dataframe :
# float64
# Data type of mentality_aggression column of Dataframe :
# float64
# Data type of mentality_interceptions column of Dataframe :
# float64
# Data type of mentality_positioning column of Dataframe :
# float64
# Data type of mentality_vision column of Dataframe :
# float64
# Data type of mentality_penalties column of Dataframe :
# float64
# Data type of mentality_composure column of Dataframe :
# float64
# Data type of defending_marking column of Dataframe :
# float64
# Data type of defending_standing_tackle column of Dataframe :
# float64
# Data type of defending_sliding_tackle column of Dataframe :
# float64
# Data type of goalkeeping_diving column of Dataframe :
# float64
# Data type of goalkeeping_handling column of Dataframe :
# float64
# Data type of goalkeeping_kicking column of Dataframe :
# float64
# Data type of goalkeeping_positioning column of Dataframe :
# float64
# Data type of goalkeeping_reflexes column of Dataframe :
# float64
# Data type of ls column of Dataframe :
# float64
# Data type of st column of Dataframe :
# float64
# Data type of rs column of Dataframe :
# float64
# Data type of lw column of Dataframe :
# float64
# Data type of lf column of Dataframe :
# float64
# Data type of cf column of Dataframe :
# float64
# Data type of rf column of Dataframe :
# float64
# Data type of rw column of Dataframe :
# float64
# Data type of lam column of Dataframe :
# float64
# Data type of cam column of Dataframe :
# float64
# Data type of ram column of Dataframe :
# float64
# Data type of lm column of Dataframe :
# float64
# Data type of lcm column of Dataframe :
# float64
# Data type of cm column of Dataframe :
# float64
# Data type of rcm column of Dataframe :
# float64
# Data type of rm column of Dataframe :
# float64
# Data type of lwb column of Dataframe :
# float64
# Data type of ldm column of Dataframe :
# float64
# Data type of cdm column of Dataframe :
# float64
# Data type of rdm column of Dataframe :
# float64
# Data type of rwb column of Dataframe :
# float64
# Data type of lb column of Dataframe :
# float64
# Data type of lcb column of Dataframe :
# float64
# Data type of cb column of Dataframe :
# float64
# Data type of rcb column of Dataframe :
# float64
# Data type of rb column of Dataframe :
# float64

# %%
y = df['value']
X = df.copy()
del X['value']

# %%
len(X.columns)
# Out:
# 93

# %%
#feature_name = list(X.columns)
# no of maximum features we need to select
#num_feats=45

# %%
Xtest = df_test

# %%
X.head()
# Out:
#    age  height_cm  weight_kg  nationality  club  ...    lb   lcb    cb   rcb    rb
# 0   21        176         72           13    18  ...  69.0  69.0  69.0  69.0  69.0
# 1   28        183         79           39   703  ...  70.0  68.0  68.0  68.0  70.0
# 2   29        172         67           78   680  ...  58.0  56.0  56.0  56.0  58.0
# 3   31        183         75           78   558  ...  41.0  44.0  44.0  44.0  41.0
# 4   25        185         75           73   409  ...  57.0  58.0  58.0  58.0  57.0
#
# [5 rows x 93 columns]

# %%
X = X.to_numpy()
y = y.to_numpy()

Xtest= Xtest.to_numpy()

# %%
len(Xtest[0])
# Out:
# 93

# %%
len(X[0])
# Out:
# 45

# %%
from sklearn.model_selection import train_test_split

# split into train test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (26283, 93) (11265, 93) (26283,) (11265,)

# %%
print(y_train[:10])
# Out:
# [11000000   180000  4200000 12000000   160000  5500000   450000   220000
#     80000  6000000]

# %%
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
sc.fit_transform(X_train)
sc.transform(X_test)
# Out:
# array([[ 0.38069839, -0.19539948, -0.90019538, ..., -0.12119196,
#         -0.12119196,  0.01841228],
#        [-0.47808464, -0.49292198, -1.04283536, ..., -0.36179446,
#         -0.36179446, -0.28071001],
#        [ 0.59539415, -1.08796698, -0.61491543, ...,  0.74497703,
#          0.74497703,  0.66651058],
#        ...,
#        [-0.47808464,  0.54840676,  0.24092442, ...,  0.88933853,
#          0.88933853,  0.76621801],
#        [ 0.38069839, -0.04663823,  0.38356439, ...,  0.69685653,
#          0.69685653,  0.76621801],
#        [ 1.66887294, -0.49292198, -0.04435553, ...,  0.74497703,
#          0.74497703,  0.66651058]])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

lin_reg = LinearRegression()
lin_reg.fit(X_train,y_train)

y_pred = lin_reg.predict(X_test)
lin_mse = mean_squared_error(y_pred,y_test)
lin_rmse = np.sqrt(lin_mse)
print('linear_train_rmse', lin_rmse) #model might be underfitting
# Out:
# linear_train_rmse 1165965.211048684

# %%
print(y_pred)
# Out:
# [  821130.91472969 18089929.6858728   1245917.18429564 ...
#    666663.08463337  -141161.18956683   -45580.45207983]

# %%
from sklearn.tree import DecisionTreeRegressor

tree_reg = DecisionTreeRegressor()
tree_reg.fit(X_train,y_train)

y_pred = tree_reg.predict(X_test)
lin_mse = mean_squared_error(y_pred,y_test)
lin_rmse = np.sqrt(lin_mse)
print('linear_train_rmse', lin_rmse) #model might be underfitting
# Out:
# linear_train_rmse 797251.7138031163

# %%
from sklearn.ensemble import RandomForestRegressor

rf_reg = RandomForestRegressor()
rf_reg.fit(X_train,y_train)

y_pred = rf_reg.predict(X_test)
rf_mse = mean_squared_error(y_pred,y_test)
rf_rmse = np.sqrt(rf_mse)
print('rf_train_rmse', rf_rmse) #model is overfitting
# Out:
# rf_train_rmse 535948.1732430612

# %%
# check xgboost version
from xgboost import XGBRegressor
model = XGBRegressor(n_estimators=1000, max_depth=7, eta=0.1, subsample=0.7, colsample_bytree=0.8)
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
xgb_mse = mean_squared_error(y_test,y_pred)
xgb_rmse = np.sqrt(xgb_mse)
print('xgb_train_rmse', xgb_rmse)
# Out:
# [07:53:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# xgb_train_rmse 384756.3976185792

# %%
from sklearn.model_selection import GridSearchCV

xgb1 = XGBRegressor()


params = {'min_child_weight':[4,5], 'gamma':[i/10.0 for i in range(3,6)],  'subsample':[i/10.0 for i in range(6,11)],
'colsample_bytree':[i/10.0 for i in range(6,11)], 'max_depth': [2,3,4]}

# Initialize XGB and GridSearch
xgb = XGBRegressor(nthread=-1) 

xgb_grid = GridSearchCV(xgb,
                        params,
                        cv = 2,
                        n_jobs = 5,
                        verbose=True)



xgb_grid.fit(X_train,
         y_train)




print(xgb_grid.best_score_)
print(xgb_grid.best_params_)
# Out:
# Fitting 2 folds for each of 450 candidates, totalling 900 fits
# [07:00:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 0.9912105964008997
# {'colsample_bytree': 0.9, 'gamma': 0.3, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 0.9}

# %%
xgb2 =  XGBRegressor(colsample_bytree= 0.9, gamma= 0.3, max_depth =4, min_child_weight= 4, subsample= 0.9)
xgb2.fit(X_train,y_train)
y_pred = xgb2.predict(X_test)
xgb_mse = mean_squared_error(y_test,y_pred)
xgb_rmse = np.sqrt(xgb_mse)
print('xgb_train_rmse', xgb_rmse)
# Out:
# [07:07:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# xgb_train_rmse 496280.6930282878

# %%
from sklearn.neighbors import KNeighborsRegressor

knn_reg = KNeighborsRegressor()
knn_reg.fit(X_train,y_train)

y_pred = knn_reg.predict(X_test)
knn_mse = mean_squared_error(y_pred,y_test)
knn_rmse = np.sqrt(knn_mse)
print('knn_train_rmse', knn_rmse) #overfiiting

# %%
from sklearn.neighbors import KNeighborsRegressor
knn_1 = KNeighborsRegressor(algorithm='auto', leaf_size=40, metric='minkowski',metric_params=None, n_jobs=None, n_neighbors=7, p=1, weights='distance')
knn_1.fit(X_train,y_train)
y_pred_knn = knn_1.predict(X_test)
knn_mse = mean_squared_error(y_pred_knn,y_test)
knn_rmse = np.sqrt(knn_mse)
print('knn_train_rmse', knn_rmse) #overfiiting

# %%
y_submit = model.predict(Xtest)

# %%
print(y_submit)
# Out:
# [5.3210176e+07 5.1793548e+07 7.7714696e+07 ... 5.1362891e+04 6.0726535e+04
#  1.3343330e+05]

# %%
df_submit = pd.DataFrame(y_submit, columns = ['predictions'])

# %%
df_submit.head()
# Out:
#    predictions
# 0   53210176.0
# 1   51793548.0
# 2   77714696.0
# 3   37967520.0
# 4   44917312.0

# %%
df_id =  pd.read_csv('FIFA_test.csv')

# %%
df_id.head()
# Out:
#                                           player_ids
# 0  [238577, 189730, 212616, 209729, 246565, 23309...
# 1  [227675, 177793, 199511, 204387, 199964, 24472...
# 2  [199522, 225810, 227740, 243139, 229771, 18347...
# 3  [223953, 222399, 231307, 196143, 212814, 24479...
# 4  [53110, 229137, 213887, 179891, 228595, 211736...

# %%
df_test_l
# Out:
# 0        167495
# 1        155862
# 2        182521
# 3        138956
# 4          9014
#           ...
# 16087    246694
# 16088    251124
# 16089    245029
# 16090    252181
# 16091    251110
# Name: sofifa_id, Length: 16092, dtype: int64

# %%
len(df_submit)
# Out:
# 16092

# %%
len(df_test_l)
# Out:
# 16092

# %%
df1 = pd.merge(df_test_l,df_submit, right_index = True,
               left_index = True)
print(df1)
# Out:
#        sofifa_id   predictions
# 0         167495  5.321018e+07
# 1         155862  5.179355e+07
# 2         182521  7.771470e+07
# 3         138956  3.796752e+07
# 4           9014  4.491731e+07
# ...          ...           ...
# 16087     246694  1.533994e+05
# 16088     251124  1.508632e+05
# 16089     245029  5.136289e+04
# 16090     252181  6.072654e+04
# 16091     251110  1.334333e+05
#
# [16092 rows x 2 columns]

# %%
len(df_id)
# Out:
# 1462

# %%
val = df1[df1['sofifa_id']==167495]['predictions']
print(val.iloc[0])
# Out:
# 53210176.0

# %%
df_id.iloc[0][0]
# Out:
# '[238577, 189730, 212616, 209729, 246565, 233090, 8631, 216047, 196143, 247728, 193092]'

# %%
def splitter(a):
  ans = []
  i = 0
  while i < len(a):
    temp = 0
    while a[i]>='0' and a[i]<='9':
      temp = int(temp*10) + int(a[i])
      i+=1
    if temp>0:
      ans.append(temp)
    i+=1
  return ans

# %%
x = splitter(df_id.iloc[0][0])
print(x)
# Out:
# [238577, 189730, 212616, 209729, 246565, 233090, 8631, 216047, 196143, 247728, 193092]

# %%
z = splitter(df_id.iloc[0][0])
val = df1[df1['sofifa_id']==z[0]]['predictions']
print(val)
# Out:
# 8900    730741.625
# Name: predictions, dtype: float32

# %%
ans =[]
for row in range(len(df_id)):
  index=-1
  val_max = 0
  x = splitter(df_id.iloc[row][0])

  for i in range(len(x)):
    val = df1[df1['sofifa_id']==x[i]]['predictions'].iloc[0]
    if val> val_max:
      val_max = val
      index = i
  ans.append(x[index])
print(ans)
# Out:
# [196143, 176619, 180403, 212814, 211736, 187072, 239970, 199254, 198347, 170481, 199827, 193283, 216468, 223627, 223208, 192789, 168607, 182521, 206511, 242348, 205086, 230354, 203747, 110974, 192593, 201262, 212622, 239331, 198617, 251182, 165153, 234333, 219455, 212240, 190460, 204104, 197838, 188876, 186839, 171833, 207984, 223749, 164468, 192774, 211300, 193581, 178746, 203668, 222982, 202695, 225021, 220132, 222391, 152993, 238224, 186805, 194171, 154950, 207877, 125871, 202884, 170320, 177326, 206485, 186805, 229473, 193082, 178086, 233785, 200228, 207566, 193130, 183353, 210333, 191202, 230317, 227476, 244915, 195864, 202695, 195586, 159985, 220710, 233866, 193147, 214379, 197233, 176270, 183895, 231235, 183556, 226807, 178160, 201024, 189908, 231150, 208450, 201455, 241686, 186115, 186684, 183220, 210864, 224030, 226414, 189251, 176949, 212811, 197756, 229391, 207441, 170320, 192883, 232097, 212198, 231919, 204104, 190558, 235176, 212459, 178051, 231281, 203042, 197891, 171877, 213661, 211117, 213400, 223154, 238621, 205407, 232270, 183389, 187517, 190264, 236786, 210761, 221363, 203486, 156616, 212616, 165229, 211382, 159983, 110677, 158138, 204776, 221695, 197445, 143745, 210008, 215568, 225341, 235374, 208295, 213134, 198717, 201455, 198329, 194879, 210679, 222900, 189280, 193897, 212814, 190264, 197756, 198710, 247131, 231612, 199110, 189819, 188086, 198856, 201515, 207566, 203213, 204550, 208330, 216466, 204307, 212811, 215639, 212911, 225359, 215259, 202652, 182493, 247181, 162932, 221434, 212245, 201452, 208450, 158626, 211338, 212240, 153079, 206167, 207454, 240702, 193283, 152729, 229237, 216594, 226747, 193839, 213400, 220061, 209782, 237369, 178509, 160009, 236007, 183574, 192593, 210864, 207863, 243630, 199482, 219652, 230407, 180930, 208596, 193116, 214394, 152908, 176919, 183820, 213655, 229636, 176676, 176994, 199577, 231235, 219626, 197891, 226379, 198329, 166706, 186942, 203965, 147782, 124375, 192622, 158138, 206141, 210327, 155976, 232432, 200054, 207935, 193222, 246748, 199556, 207858, 220182, 207645, 176993, 209297, 230564, 229606, 215256, 183900, 239641, 226108, 221540, 45186, 142721, 198009, 191055, 223495, 208585, 223197, 217047, 211382, 220035, 50542, 220209, 198776, 210896, 191687, 184134, 223524, 171579, 184823, 221885, 190887, 229261, 206467, 241486, 194334, 208141, 231280, 162221, 160146, 170903, 188042, 219626, 232270, 226491, 205175, 156713, 228941, 216139, 176993, 168354, 214040, 203574, 205669, 236295, 180206, 186130, 180819, 180714, 236007, 45595, 201931, 199952, 237799, 201399, 144429, 236690, 207410, 183498, 210047, 212459, 202857, 235805, 235634, 200073, 204838, 232432, 216468, 199580, 158232, 180635, 204963, 246309, 229147, 203604, 223248, 199577, 184431, 227790, 203888, 190778, 220948, 244263, 228336, 208251, 221896, 208670, 219571, 192593, 169595, 183556, 193061, 230967, 160126, 219626, 201956, 196978, 163301, 220570, 205988, 235889, 225997, 205869, 176676, 186351, 193352, 157304, 225341, 170320, 221219, 202166, 212219, 219451, 231786, 210126, 210047, 226162, 230850, 208808, 168585, 210258, 225356, 191687, 189513, 203362, 198538, 188388, 233986, 166706, 242201, 198810, 197031, 181318, 192126, 178284, 215256, 211056, 104389, 215018, 235353, 216939, 243630, 219626, 229453, 173221, 223061, 204082, 195363, 203483, 203747, 205402, 203505, 192557, 201931, 193077, 189332, 198717, 211454, 177358, 225161, 199986, 223074, 193953, 234612, 171833, 212491, 222429, 220793, 213956, 241907, 204102, 210126, 230276, 188005, 184344, 220337, 170570, 203376, 205193, 216079, 193283, 216594, 54050, 239845, 139997, 166074, 216409, 205998, 240898, 209499, 177934, 225508, 176993, 230183, 206113, 167549, 202493, 206436, 180819, 189196, 159028, 206649, 211320, 215333, 181786, 231280, 233260, 204830, 232411, 223959, 231823, 169195, 235997, 189251, 233993, 212622, 211300, 214026, 225850, 229496, 213648, 187072, 213556, 209769, 192012, 225100, 204970, 208093, 185373, 194404, 212491, 190520, 229104, 251696, 222 ...

# %%
y_ans = np.array(ans)

# %%
len(df_id)
# Out:
# 1462

# %%
output = pd.DataFrame({'player_ids':df_id['player_ids'], 'most_valued_player_id':y_ans})
output.to_csv('submission.csv', index=False)

# %%
x = [238577, 189730, 212616, 209729, 246565, 233090, 8631, 216047, 196143, 247728, 193092]
for i in x:
   print(df1[df1['sofifa_id']==i]['predictions'].iloc[0])
# Out:
# 730741.6
# 445333.25
# 8431216.0
# 3858989.0
# 713150.1
# 345230.6
# 846624.44
# 523149.7
# 9279898.0
# 331530.4
# 1215817.6
